# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
data = pd.read_csv('INR=X.csv')
data
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 0    2021-10-27  74.888901  75.093002  74.888901  74.888901  74.888901       0
# 1    2021-10-28  75.037697  75.322502  74.754501  75.050003  75.050003       0
# 2    2021-10-29  74.796997  75.025299  74.737999  74.797203  74.797203       0
# 3    2021-11-01  74.928398  75.186302  74.810501  74.928299  74.928299       0
# 4    2021-11-02  74.829903  74.909302  74.613297  74.829903  74.829903       0
# ..          ...        ...        ...        ...        ...        ...     ...
# 257  2022-10-21  82.825699  83.220001  82.562302  82.825699  82.825699       0
# 258  2022-10-24  82.541298  83.068901  82.541298  82.541298  82.541298       0
# 259  2022-10-25  82.761497  83.137497  82.430000  82.761497  82.761497       0
# 260  2022-10-26  82.445297  82.550598  81.924202  82.445297  82.445297       0
# 261  2022-10-27  81.901001  82.550003  81.901001  82.366997  82.366997       0
#
# [262 rows x 7 columns]

# %%
from seaborn import regression
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
# Out:
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.997533  0.997767  0.999833   0.999833     NaN
# High       0.997533  1.000000  0.997382  0.997536   0.997536     NaN
# Low        0.997767  0.997382  1.000000  0.997811   0.997811     NaN
# Close      0.999833  0.997536  0.997811  1.000000   1.000000     NaN
# Adj Close  0.999833  0.997536  0.997811  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN

# %%
sns.heatmap(data.corr())
plt.show()

# %%
x = data[['Open', 'High', 'Low']]
y = data['Close']
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest,  ytrain, ytest = train_test_split(x, y , test_size = 0.2, random_state = 42)

# %%
    
    from sklearn.tree import DecisionTreeRegressor
    model = DecisionTreeRegressor()
    model.fit(xtrain, ytrain)
    
 

    print('[1]logistic regression training accuracy: ',model.score(xtrain,ytrain))
# Out:
# [1]logistic regression training accuracy:  1.0

# %%
plt.figure(figsize = (20,10))
ypred = model.predict(xtest)
plt.plot(ytest, color = 'green')
plt.plot(xtes, color = 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ytest
